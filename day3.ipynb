# %%
#!pip install datadotworld
#!pip install datadotworld[pandas]

# %%
# !dw configure

# %%
from google.colab import drive
import numpy as np
import pandas as pd

import datadotworld as dw

# %%
# ROOT='/content/drive'
# drive.mount(ROOT)

# %%
cd 'drive/My Drive/Colab Notebooks/'
# Out:
# [Errno 2] No such file or directory: 'drive/My Drive/Colab Notebooks/'
# /content/drive/My Drive/Colab Notebooks/matrix

# %%
cd 'matrix'
# Out:
# /content/drive/My Drive/Colab Notebooks/matrix

# %%
ls
# Out:
# day3.ipynb  LICENSE  README.md  TestColabToGitHub.ipynb

# %%
# !mkdir data

# %%
# !echo 'data' > .gitignore

# %%
# !git add .gitignore

# %%
data=dw.load_dataset('datafiniti/mens-shoe-prices')

# %%
data.dataframes
# Out:
# LazyLoadedDict({'7004_1': LazyLoadedValue(<pandas.DataFrame>)})

# %%
df=data.dataframes['7004_1']
df.shape
# Out:
# /usr/local/lib/python3.6/dist-packages/datadotworld/models/dataset.py:209: UserWarning: Unable to set data frame dtypes automatically using 7004_1 schema. Data types may need to be adjusted manually. Error: Integer column has NA values in column 10
#   'Error: {}'.format(resource_name, e))
# /usr/local/lib/python3.6/dist-packages/datadotworld/util.py:121: DtypeWarning: Columns (39,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   return self._loader_func()
# (19387, 48)

# %%
df.sample(5)
# Out:
#                          id asins         brand  ...  vin websiteids    weight
# 15466  AVpfj_xjilAPnD_xeB1B   NaN   VALUE BRAND  ...  NaN        NaN  4.95 lbs
# 3096   AVpe_jh7ilAPnD_xSkJM   NaN         VENUM  ...  NaN        NaN       NaN
# 14852  AVpfcR7l1cnluZ0-k03f   NaN  Justin Boots  ...  NaN        NaN       NaN
# 2741   AVpfLZq51cnluZ0-fk32   NaN          Nike  ...  NaN        NaN       NaN
# 7081   AVpfOmHmLJeJML435GLp   NaN        Pakems  ...  NaN        NaN       NaN
#
# [5 rows x 48 columns]

# %%
df.columns
# Out:
# Index(['id', 'asins', 'brand', 'categories', 'colors', 'count', 'dateadded',
#        'dateupdated', 'descriptions', 'dimension', 'ean', 'features',
#        'flavors', 'imageurls', 'isbn', 'keys', 'manufacturer',
#        'manufacturernumber', 'merchants', 'name', 'prices_amountmin',
#        'prices_amountmax', 'prices_availability', 'prices_color',
#        'prices_condition', 'prices_count', 'prices_currency',
#        'prices_dateadded', 'prices_dateseen', 'prices_flavor', 'prices_issale',
#        'prices_merchant', 'prices_offer', 'prices_returnpolicy',
#        'prices_shipping', 'prices_size', 'prices_source', 'prices_sourceurls',
#        'prices_warranty', 'quantities', 'reviews', 'sizes', 'skus',
#        'sourceurls', 'upc', 'vin', 'websiteids', 'weight'],
#       dtype='object')

# %%
df.prices_currency.unique()
# Out:
# array(['USD', 'AUD', 'CAD', 'EUR', nan, 'GBP', 'New with box',
#        'UnbeatableSale.com, Inc. - Walmart.com',
#        'PalmBeach Jewelry - Walmart.com', 'new', 'New without tags',
#        'SHOEBACCA LTD. - Walmart.com', 'Shoes.com',
#        'Wholesale Costume and Party Supplies - Walmart.com'], dtype=object)

# %%
df.prices_currency.value_counts()
# Out:
# USD                                                   18524
# AUD                                                     338
# CAD                                                     303
# EUR                                                     107
# GBP                                                      22
# UnbeatableSale.com, Inc. - Walmart.com                    3
# New with box                                              3
# PalmBeach Jewelry - Walmart.com                           3
# new                                                       3
# Wholesale Costume and Party Supplies - Walmart.com        2
# Shoes.com                                                 1
# SHOEBACCA LTD. - Walmart.com                              1
# New without tags                                          1
# Name: prices_currency, dtype: int64

# %%
df.prices_currency.value_counts(normalize=True)
# Out:
# USD                                                   0.959246
# AUD                                                   0.017503
# CAD                                                   0.015691
# EUR                                                   0.005541
# GBP                                                   0.001139
# UnbeatableSale.com, Inc. - Walmart.com                0.000155
# New with box                                          0.000155
# PalmBeach Jewelry - Walmart.com                       0.000155
# new                                                   0.000155
# Wholesale Costume and Party Supplies - Walmart.com    0.000104
# Shoes.com                                             0.000052
# SHOEBACCA LTD. - Walmart.com                          0.000052
# New without tags                                      0.000052
# Name: prices_currency, dtype: float64

# %%
df_usd= df[df.prices_currency=='USD'].copy()

# %%
df_usd.prices_currency.unique()
# Out:
# array(['USD'], dtype=object)

# %%
df_usd.prices_amountmin.head()
# Out:
# 0    39.89
# 1    51.99
# 2    40.02
# 3    50.31
# 4    46.26
# Name: prices_amountmin, dtype: float64

# %%
df_usd.prices_amountmin=df_usd.prices_amountmin.astype(float)

# %%
df_usd.prices_amountmin.hist()

# %%
filter_max=np.percentile(df_usd.prices_amountmin,99)
filter_max
# Out:
# 895.0

# %%
df_usd_filtered=df_usd[df_usd.prices_amountmin<filter_max]

# %%
df_usd_filtered.prices_amountmin.hist(bins=100)

# %%
# !git add day3pawel.ipynb

# %%
# !git commit -m "load man shoues price data"
# Out:
# [master ee7c908] load man shoues price data
#  1 file changed, 1 insertion(+)
#  create mode 100644 day3pawel.ipynb

# %%
# !git config --global user.email "pawel.w.krawczyk@gmail.com"
# !git config --global user.name "Pawel Krawczyk"

# %%
# !git commit -m "load man shoues price data"
# Out:
# On branch master
# Your branch is ahead of 'origin/master' by 2 commits.
#   (use "git push" to publish your local commits)
#
# Changes not staged for commit:
# 	deleted:    day3.ipynb
#
# no changes added to commit

# %%
# !git push -u origin master
# Out:
# fatal: could not read Password for 'https://07488eca22cd8e51428f2a20e0db68d250487ef7@github.com': No such device or address

# %%
# !git pull --no-commit
# Out:
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 2 (delta 1), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (2/2), done.
# From https://github.com/pawel-krawczyk/matrix
#    2ec0e99..91a7e25  master     -> origin/master
# CONFLICT (modify/delete): day3.ipynb deleted in 91a7e2522ba2f5f3c2a718a3e2250d01952444f3 and modified in HEAD. Version HEAD of day3.ipynb left in tree.
# Automatic merge failed; fix conflicts and then commit the result.
